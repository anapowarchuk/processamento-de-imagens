# %% [markdown]
# <a href="https://colab.research.google.com/github/anapowarchuk/processamento-de-imagens/blob/main/Aula_3_Redimencionamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Material elaborado por Ana Xavier, durante as aulas de Processamento Digitais de Imagens, ministradas pela Professora Dra. Carla Diniz L. Becker, para o curso de Informática Biomédica da Universidade Federal de Ciências da Saúde de Porto Alegre. - Feito no Google Colab

# %% [markdown]
# # **Aula 3: Redimensionamento**
# ### 18/11/2021 [Assíncrona]

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)

# %%
import cv2 # importando a biblioteca OpenCv
import numpy as np 
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
# Leitura da imagem com a função imread()
#imagem = cv2.imread('lena512.bmp')
imagem = cv2.imread('lena.png')
print('Largura em pixels: ', end='')
print(imagem.shape[1]) #largura da imagem
print('Altura em pixels: ', end='')
print(imagem.shape[0]) #altura da imagem
print('Qtde de canais: ', end='')
print(imagem.shape[2])
# Out:
# Largura em pixels: 512
# Altura em pixels: 512
# Qtde de canais: 3

# %%
import numpy as np
import cv2

#comando resize

imagem = cv2.imread('lena.png')
cv2_imshow(imagem)
cv2.waitKey(0)
cv2.destroyAllWindows()
largura = img.shape[1]
altura = img.shape[0]

#Para reduzir ou aumentar o tamanho da imagem, existe uma função já pronta do OpenCV, trata-se da função ‘resize’.
#Note que é preciso calcular a proporção da altura em relação a largura da nova imagem, caso contrário ela poderá ficar
#distorcida

proporcao = float(altura/largura)
largura_nova = 200 #em pixels
altura_nova = int(largura_nova*proporcao)
tamanho_novo = (largura_nova, altura_nova)

img_redimensionada = cv2.resize(img, tamanho_novo, interpolation = cv2.INTER_AREA)

#A função ‘rezise’ utiliza uma propriedade aqui definida como cv2.INTER_AREA que é uma especificação
#do cálculo matemático para redimensionar a imagem. Porém, caso a imagem seja redimensionada para um tamanho maior é preciso
#ponderar que ocorrerá perda de qualidade. 

cv2_imshow( img_redimensionada)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F560AA33290>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F560A98A910>

# %%
import cv2
from google.colab.patches import cv2_imshow

#comando crop

imagem = cv2.imread('lena.png')
recorte = imagem[50:300, 50:300]
cv2_imshow(recorte)
cv2.waitKey(0)
cv2.destroyAllWindows()

#salvando a nova imagem - jupyter
#import numpy as np
#import cv2
# cv2_imwrite("recorte.png", recorte) #salva no disco
# Out:
# <PIL.Image.Image image mode=RGB size=250x250 at 0x7F560AA41B90>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

#comando getRotationMatrix2D

img = cv2.imread('lena.png')
(alt, lar) = img.shape[:2] #captura altura e largura
centro = (lar // 2, alt // 2) #acha o centro
M = cv2.getRotationMatrix2D(centro, 60, 1.0) #rotação em 60 graus
img_rotacionada = cv2.warpAffine(img, M, (lar, alt))
cv2_imshow(img_rotacionada)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F5609931C10>
